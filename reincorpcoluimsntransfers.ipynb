# %%
import pandas as pd

# Carica il file CSV in un DataFrame
df = pd.read_csv('transfers.csv')

# Crea un nuovo DataFrame con le colonne desiderate e valori unici
new_df = df[['club_name', 'league_name']].drop_duplicates()

# Stampa il nuovo DataFrame
print(new_df)
# Out:
#                 club_name       league_name
# 0         Athletic Bilbao  Primera Division
# 1              Granada CF  Primera Division
# 5               Getafe CF  Primera Division
# 8              Levante UD  Primera Division
# 11            Valencia CF  Primera Division
# ...                   ...               ...
# 6857            FC Empoli           Serie A
# 6863  US Salernitana 1919           Serie A
# 6866           Venezia FC           Serie A
# 6985         US Cremonese           Serie A
# 6994             AC Monza           Serie A
#
# [246 rows x 2 columns]

# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# Carica il file CSV in un DataFrame
df = pd.read_csv('transfers.csv')

# Crea un nuovo DataFrame con le colonne desiderate e valori unici
new_df = df[['club_name', 'league_name']].drop_duplicates()

# Funzione per trovare il "miglior match"
def find_best_match(row):
    club_name = row['club_involved_name']
    best_match = process.extractOne(club_name, new_df['club_name'])
    if best_match[1] >= 95:
        return new_df.loc[best_match[2], 'league_name']
    else:
        return None

# Aggiungi la colonna "league_destination" al DataFrame originale
df['league_destination'] = df.apply(find_best_match, axis=1)

# Stampa il DataFrame con la colonna "league_destination" aggiunta
print(df)
# Out:
#             club_name            player_name   age            position  \
# 0     Athletic Bilbao           Aritz Aduriz  31.0      Centre-Forward
# 1          Granada CF       Youssef El Arabi  25.0      Centre-Forward
# 2          Granada CF                  Allan  21.0  Defensive Midfield
# 3          Granada CF            Borja Gómez  24.0         Centre-Back
# 4          Granada CF          Silvan Widmer  19.0          Right-Back
# ...               ...                    ...   ...                 ...
# 7006   Udinese Calcio        Matheus Martins  19.0         Left Winger
# 7007    Spezia Calcio  Przemyslaw Wisniewski  24.0         Centre-Back
# 7008    Spezia Calcio       Raimonds Krollis  21.0      Centre-Forward
# 7009    Spezia Calcio              Tio Cipot  19.0    Central Midfield
# 7010         US Lecce      Tommaso Cassandro  23.0          Right-Back
#
#      club_involved_name transfer_period  fee_cleaned       league_name  \
# 0              Valencia          Summer         2.50  Primera Division
# 1          Al-Hilal SFC          Summer         5.00  Primera Division
# 2             Maldonado          Summer         3.00  Primera Division
# 3               Karpaty          Summer         0.80  Primera Division
# 4              FC Aarau          Summer         0.75  Primera Division
# ...                 ...             ...          ...               ...
# 7006         Fluminense          Winter         6.00           Serie A
# 7007            Venezia          Winter         4.00           Serie A
# 7008           Valmiera          Winter         1.50           Serie A
# 7009            NS Mura          Winter         0.70           Serie A
# 7010         Cittadella          Winter         0.40           Serie A
#
#          season  OverallSeasonClub  OverallSeasonClub2 league_destination
# 0     2012/2013           0.005126            0.071733   Primera Division
# 1     2012/2013           0.000000            0.000000               None
# 2     2012/2013           0.000000            0.000000               None
# 3     2012/2013           0.000000            0.000000               None
# 4     2012/2013           0.000000            0.000000               None
# ...         ...                ...                 ...                ...
# 7006  2022/2023           0.000000            0.000000               None
# 7007  2022/2023           0.000000            0.000000            Serie A
# 7008  2022/2023           0.000000            0.000000               None
# 7009  2022/2023           0.000000            0.000000               None
# 7010  2022/2023           0.000000            0.000000               None
#
# [7011 rows x 12 columns]

# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process


# Carica il file CSV teamtry235 in un DataFrame
teamtry235 = pd.read_csv('teamtry235.csv')

# Carica il file CSV df in un DataFrame
df = df

# Funzione per trovare il "miglior match"
def find_best_match(row):
    club_name = row['club_name']
    best_match = process.extractOne(club_name, teamtry235['name22'])
    if best_match[1] >= 95:
        return teamtry235.loc[best_match[2], 'Overall']
    else:
        return 0

# Aggiungi la colonna "Overall_club_name" al DataFrame df
df['Overall_club_name'] = df.apply(find_best_match, axis=1)

# Stampa il DataFrame df con la colonna "Overall_club_name" aggiunta
print(df)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
#
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "C:\Users\Utente\anaconda4\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-803f591ab0a2>", line 22, in <module>
#     df['Overall_club_name'] = df.apply(find_best_match, axis=1)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\pandas\core\frame.py", line 8740, in apply
#     return op.apply()
#   File "C:\Users\Utente\anaconda4\lib\site-packages\pandas\core\apply.py", line 688, in apply
#     return self.apply_standard()
#   File "C:\Users\Utente\anaconda4\lib\site-packages\pandas\core\apply.py", line 812, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "C:\Users\Utente\anaconda4\lib\site-packages\pandas\core\apply.py", line 828, in apply_series_generator
#     results[i] = self.f(v)
#   File "<ipython-input-3-803f591ab0a2>", line 15, in find_best_match
#     best_match = process.extractOne(club_name, teamtry235['name22'])
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\process.py", line 220, in extractOne
#     return max(best_list, key=lambda i: i[1])
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\process.py", line 110, in extractWithoutOrder
#     score = scorer(processed_query, processed)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\fuzz.py", line 289, in WRatio
#     ptsor = partial_token_sort_ratio(p1, p2, full_process=False) \
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\fuzz.py", line 112, in partial_token_sort_ratio
#     return _token_sort(s1, s2, partial=True, force_ascii=force_ascii, full_process=full_process)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\utils.py", line 38, in decorator
#     return func(*args, **kwargs)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\fuzz.py", line 96, in _token_sort
#     return partial_ratio(sorted1, sorted2)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\utils.py", line 38, in decorator
#     return func(*args, **kwargs)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\utils.py", line 29, in decorator
#     return func(*args, **kwargs)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\utils.py", line 47, in decorator
#     return func(*args, **kwargs)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\fuzz.py", line 47, in partial_ratio
#     blocks = m.get_matching_blocks()
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\StringMatcher.py", line 58, in get_matching_blocks
#     self._matching_blocks = matching_blocks(self.get_opcodes(),
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\StringMatcher.py", line 45, in get_opcodes
#     self._opcodes = opcodes(self._str1, self._str2)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\Levenshtein\__init__.py", line 343, in opcodes
#     return _Levenshtein.opcodes(arg1, arg2).as_list()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Utente\anaconda4\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Utente\anaconda4\lib\site-packages\IPython\core\ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\IPython\core\ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\IPython\core\ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "C:\Users\Utente\anaconda4\lib\inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "C:\Users\Utente\anaconda4\lib\inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "C:\Users\Utente\anaconda4\lib\inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "C:\Users\Utente\anaconda4\lib\inspect.py", line 751, in getmodule
#     f = getabsfile(module)
#   File "C:\Users\Utente\anaconda4\lib\inspect.py", line 720, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "C:\Users\Utente\anaconda4\lib\inspect.py", line 705, in getsourcefile
#     if os.path.exists(filename):
#   File "C:\Users\Utente\anaconda4\lib\genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "C:\Users\Utente\anaconda4\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-3-803f591ab0a2>", line 22, in <module>
#     df['Overall_club_name'] = df.apply(find_best_match, axis=1)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\pandas\core\frame.py", line 8740, in apply
#     return op.apply()
#   File "C:\Users\Utente\anaconda4\lib\site-packages\pandas\core\apply.py", line 688, in apply
#     return self.apply_standard()
#   File "C:\Users\Utente\anaconda4\lib\site-packages\pandas\core\apply.py", line 812, in apply_standard
#     results, res_index = self.apply_series_generator()
#   File "C:\Users\Utente\anaconda4\lib\site-packages\pandas\core\apply.py", line 828, in apply_series_generator
#     results[i] = self.f(v)
#   File "<ipython-input-3-803f591ab0a2>", line 15, in find_best_match
#     best_match = process.extractOne(club_name, teamtry235['name22'])
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\process.py", line 220, in extractOne
#     return max(best_list, key=lambda i: i[1])
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\process.py", line 110, in extractWithoutOrder
#     score = scorer(processed_query, processed)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\fuzz.py", line 289, in WRatio
#     ptsor = partial_token_sort_ratio(p1, p2, full_process=False) \
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\fuzz.py", line 112, in partial_token_sort_ratio
#     return _token_sort(s1, s2, partial=True, force_ascii=force_ascii, full_process=full_process)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\utils.py", line 38, in decorator
#     return func(*args, **kwargs)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\fuzz.py", line 96, in _token_sort
#     return partial_ratio(sorted1, sorted2)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\utils.py", line 38, in decorator
#     return func(*args, **kwargs)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\utils.py", line 29, in decorator
#     return func(*args, **kwargs)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\utils.py", line 47, in decorator
#     return func(*args, **kwargs)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\fuzz.py", line 47, in partial_ratio
#     blocks = m.get_matching_blocks()
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\StringMatcher.py", line 58, in get_matching_blocks
#     self._matching_blocks = matching_blocks(self.get_opcodes(),
#   File "C:\Users\Utente\anaconda4\lib\site-packages\fuzzywuzzy\StringMatcher.py", line 45, in get_opcodes
#     self._opcodes = opcodes(self._str1, self._str2)
#   File "C:\Users\Utente\anaconda4\lib\site-packages\Levenshtein\__init__.py", line 343, in opcodes
#     return _Levenshtein.opcodes(arg1, arg2).as_list()
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\Utente\anaconda4\lib\site-packages\IPython\core\interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# KeyboardInterrupt

# %%
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# Carica il file CSV teamtry235 in un DataFrame
teamtry235 = pd.read_csv('teamtry235.csv')

# Carica il file CSV df in un DataFrame
df = df

# Funzione per trovare il "miglior match"
def find_best_match(row):
    club_name = row['club_involved_name']
    best_match = process.extractOne(club_name, teamtry235['name22'])
    if best_match[1] >= 95:
        return teamtry235.loc[best_match[2], 'Overall']
    else:
        return 0

# Aggiungi la colonna "Overall_club_name" al DataFrame df
df['Overall_club_involved'] = df.apply(find_best_match, axis=1)

# Stampa il DataFrame df con la colonna "Overall_club_name" aggiunta
print(df)

# %%
df.to_csv("C:/Users/Utente/Desktop/cakio/dcereijo-player-scores/data/transfers3.csv", index=False)

# %%
import pandas as pd

# Carica il file CSV df in un DataFrame
df = pd.read_csv('transfers3.csv')

# Droppa le righe contenenti "0" o "None" in qualsiasi colonna
df = df.replace({'0': None, 'None': None})  # Sostituisci '0' e 'None' con None
df = df.dropna()  # Droppa le righe contenenti valori nulli

# Resetta gli indici
df = df.reset_index(drop=True)

# Stampa il DataFrame risultante
print(df)

# Salva il DataFrame risultante in un nuovo file CSV
df.to_csv('transfers_filtered.csv', index=False)

# %%
df = df[df['fee_cleaned'] >= 10]
df.to_csv("C:/Users/Utente/Desktop/cakio/dcereijo-player-scores/data/transferspochi.csv", index=False)

print(df)

# %%
import pandas as pd

# Load the dataset from the CSV file
data = pd.read_csv("C:/Users/Utente/Desktop/cakio/dcereijo-player-scores/data/transfers3.csv")

# Extract only the first 4 digits of the "season" column
data['season'] = data['season'].astype(str).str[:4]

# Print the modified dataset
print(data)

# %%
data.to_csv("C:/Users/Utente/Desktop/cakio/dcereijo-player-scores/data/transfers4.csv", index=False)

# %%
# Create two separate dataframes based on the conditions
df_2012_to_2021 = data[data['season'].astype(int) <= 2021]
df_2022 = data[data['season'] == '2022']

# Save the dataframes to separate CSV files
df_2012_to_2021.to_csv("C:/Users/Utente/Desktop/cakio/dcereijo-player-scores/data/transfers45train.csv", index=False)
df_2022.to_csv("C:/Users/Utente/Desktop/cakio/dcereijo-player-scores/data/transfers35test.csv", index=False)
